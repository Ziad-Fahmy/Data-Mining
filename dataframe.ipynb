# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziad-Fahmy/Data-Mining/blob/main/dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.seed(100)
df = pd.DataFrame(np.random.randn(5,4).reshape(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318

# %%
df.loc['A']
# Out:
# W   -1.749765
# X    0.342680
# Y    1.153036
# Z   -0.252436
# Name: A, dtype: float64

# %%
df.iloc[3]
# Out:
# W   -0.583595
# X    0.816847
# Y    0.672721
# Z   -0.104411
# Name: D, dtype: float64

# %%
df.loc[['A',
'B']]
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043

# %%
df.iloc[2:5]
# Out:
#           W         X         Y         Z
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318

# %%
df.loc['A']['W']
# Out:
# -1.7497654730546974

# %%
df.loc['V']={'W':1,'X':2,'Y':3,'Z':4}

# %%
df
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318
# V  1.000000  2.000000  3.000000  4.000000

# %%
df.loc['H']= df.loc['A'] + df.loc['B']

# %%
df
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318
# V  1.000000  2.000000  3.000000  4.000000
# H -0.768445  0.856899  1.374215 -1.322479

# %%
df.drop('H',axis=0)
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318
# V  1.000000  2.000000  3.000000  4.000000

# %%
df
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318
# V  1.000000  2.000000  3.000000  4.000000
# H -0.768445  0.856899  1.374215 -1.322479

# %%
df.drop('H',axis=0,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318
# V  1.000000  2.000000  3.000000  4.000000
